# %%
import os
import faiss
import numpy as np
from tqdm import tqdm
from sentence_transformers import SentenceTransformer

# %% [markdown]
# ## Этап 1. Загрузка текстов из файлов

# %%
TEXT_FILES_DIR = "garant"

# %%
def load_texts_from_folder(folder_path):
    texts = []
    filenames = []
    for file in tqdm(sorted(os.listdir(folder_path)), desc="Загрузка текстов"):
        if file.endswith(".txt"):
            file_path = os.path.join(folder_path, file)
            with open(file_path, "r", encoding="utf-8") as f:
                text = f.read().strip()
                texts.append(text)
                filenames.append(file)
    return texts, filenames

# %%
texts, filenames = load_texts_from_folder(TEXT_FILES_DIR)
# Out:
# Загрузка текстов: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████| 1628/1628 [00:02<00:00, 643.29it/s]

# %% [markdown]
# ## Этап 2. Создание эмбеддингов

# %%
MODEL_NAME = "DeepPavlov/rubert-base-cased"
model = SentenceTransformer(MODEL_NAME)
# Out:
# No sentence-transformers model found with name DeepPavlov/rubert-base-cased. Creating a new one with mean pooling.
# Some weights of the model checkpoint at DeepPavlov/rubert-base-cased were not used when initializing BertModel: ['cls.predictions.bias', 'cls.predictions.decoder.bias', 'cls.predictions.decoder.weight', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.dense.bias', 'cls.predictions.transform.dense.weight', 'cls.seq_relationship.bias', 'cls.seq_relationship.weight']
# - This IS expected if you are initializing BertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).

# %%
text_embeddings = model.encode(texts, batch_size=16, convert_to_numpy=True, show_progress_bar=True)
print(f"\nРазмерность эмбеддингов: {text_embeddings.shape}")
# Out:
# Batches:   0%|          | 0/102 [00:00<?, ?it/s]
# Размерность эмбеддингов: (1628, 768)

# %% [markdown]
# ## Этап 3: Создание FAISS-индекса

# %% [markdown]
# FAISS используется для быстрого поиска среди эмбеддингов

# %%
norms = np.linalg.norm(text_embeddings, axis=1, keepdims=True)
text_embeddings_normalized = text_embeddings / norms
dimension = text_embeddings.shape[1]

# %% [markdown]
# Создаём FAISS-индекс

# %%
index = faiss.IndexFlatL2(dimension)
index.add(text_embeddings_normalized.astype('float32'))

# %% [markdown]
# Сохраняем индекс для последующего использования

# %%
faiss.write_index(index, "results_DeepPavlov_Default/text_index.faiss")
np.save("results_DeepPavlov_Default/filenames.npy", np.array(filenames))  # сохраняем список имён файлов

# %% [markdown]
# ## Этап 4: Функция поиска похожих текстов

# %%
def find_similar_texts(query, top_k=5):
    query_embedding = model.encode([query], convert_to_numpy=True) # преобразуем запрос в эмбеддинг
    distances, indices = index.search(query_embedding, top_k) # выполняем поиск в FAISS

    print("Наиболее похожие тексты:")
    for i, idx in enumerate(indices[0]):
        print(f"{i+1}. {filenames[idx]} (дистанция: {distances[0][i]:.4f})")
        print(texts[idx][:300] + "...")  # выводим первые 300 символов текста
        print("-" * 80)

# %%
query_text = "Международный день инвалидов в Хабаровске"
find_similar_texts(query_text, top_k=20)
# Out:
# Наиболее похожие тексты:
# 1. garant_1660.txt (дистанция: 62.8300)
# ﻿
# Закон Санкт-Петербурга от 18 октября 2004 г. N 492-72
# "О внесении изменения в Закон Санкт-Петербурга
# "О налоге на игорный бизнес в Санкт-Петербурге"
# (Принят Законодательным Собранием Санкт-Петербурга
# 6 октября 2004 года)
#
# Статья 1
# Внести в Закон Санкт-Петербурга от 22 октября 2003 года N 623-94 "О...
# --------------------------------------------------------------------------------
# 2. garant_0763.txt (дистанция: 62.9080)
# ﻿
# Постановление Правительства Ханты-Мансийского АО - Югры от 5 ноября 2004 г. N 437-п
# "Об установлении величины прожиточного минимума в Ханты-Мансийском автономном округе - Югре
# за III квартал 2004 года"
#
#
# В соответствии с Федеральным законом от 24.10.97 N 134-ФЗ "О прожиточном минимуме в Российско...
# --------------------------------------------------------------------------------
# 3. garant_1261.txt (дистанция: 63.0506)
# ﻿
# Постановление Мэра г. Хабаровска
# от 11 ноября 2004 г. N 1650
# "О проведении Международного дня инвалидов в городе Хабаровске в 2004 году"
#
# В связи с проведением 3 декабря 2004 года Международного дня инвалидов и в целях привлечения внимания широких слоев общественности города, предприятий, учрежден...
# --------------------------------------------------------------------------------
# 4. garant_1180.txt (дистанция: 63.0538)
# ﻿
# Закон Санкт-Петербурга от 29 декабря 2004 г. N 692-101
# "Об установлении цены земли в Санкт-Петербурге"
# (Принят Законодательным Собранием Санкт-Петербурга 22 декабря 2004 года)
#
# В соответствии с Законом Российской Федерации "О плате за землю", пунктом 2 статьи 2 Федерального закона "О введении в де...
# --------------------------------------------------------------------------------
# 5. garant_1653.txt (дистанция: 63.0975)
# ﻿
# Постановление Правительства Ленинградской области
# от 28 октября 2004 г. N 236
# "Об установлении величины прожиточного минимума на душу населения
# и по основным социально-демографическим группам населения
# в Ленинградской области за третий квартал 2004 года"
#
# В соответствии с Федеральным законом "О пр...
# --------------------------------------------------------------------------------
# 6. garant_0625.txt (дистанция: 63.0994)
# ﻿
# Постановление Администрации Псковской области
# от 25 октября 2004 г. N 441
# "Об установлении величины прожиточного минимума на душу населения и по
# основным социально-демографическим группам населения в Псковской
# области за III квартал 2004 года"
#
# В соответствии с Федеральным законом от 24.10.97 N 13...
# --------------------------------------------------------------------------------
# 7. garant_0912.txt (дистанция: 63.1164)
# ﻿
# Постановление Мэра города Томска от 13 августа 2004 г. N 406
# "О регулировании розничной продажи алкогольной продукции на территории г.Томска
# в дни празднования юбилея города"
#
# В связи с празднованием 400-летия города Томска, в целях поддержания общественного порядка в местах организации и провед...
# --------------------------------------------------------------------------------
# 8. garant_0682.txt (дистанция: 63.1439)
# ﻿
# Решение Омского городского Совета
# от 21 июля 2004 г. N 197
# "Об установлении доплаты отдельным категориям граждан,
# имеющих почетные звания СССР, РСФСР и Российской Федерации"
#
# Учитывая значительный вклад отдельных категорий специалистов в развитие образования, культуры, здравоохранения, физической ...
# --------------------------------------------------------------------------------
# 9. garant_0592.txt (дистанция: 63.1725)
# ﻿
# Решение Челябинской городской Думы от 7 декабря 2004 г. N 41/11
# "О принятии городской целевой программы "О праздновании 60-й годовщины
# Победы в Великой Отечественной войне 1941-1945 годов в городе Челябинске"
#
# В связи с 60-летием со дня Победы советского народа в Великой Отечественной войне 1941...
# --------------------------------------------------------------------------------
# 10. garant_0522.txt (дистанция: 63.1730)
# ﻿
# Постановление Мэра г. Хабаровска
# от 1 декабря 2004 г. N 1762
# "О проведении в 2005 году творческого конкурса средств массовой
# информации г. Хабаровска, посвященного 60-летию Победы в Великой
# Отечественной войне"
#
# В ознаменование предстоящего 9 мая 2005 года 60-летия Победы советского народа в Велик...
# --------------------------------------------------------------------------------
# 11. garant_0274.txt (дистанция: 63.1851)
# ﻿
# Распоряжение Мэра г. Калининграда от 9 ноября 2004 г. N 956-р
# "Об утверждении суммы оплаты за содержание в муниципальных стационарных
# учреждениях социального обслуживания престарелых граждан и инвалидов"
#
# В связи с ростом цен на услуги предприятий коммунального хозяйства, энергоносители, медикамен...
# --------------------------------------------------------------------------------
# 12. garant_0531.txt (дистанция: 63.2112)
# ﻿
# Закон Ханты-Мансийского АО - Югры от 7 декабря 2004 г. N 72-оз
# "О внесении изменений в закон Ханты-Мансийского автономного округа
# "О порядке назначения и деятельности мировых судей
# в Ханты-Мансийском автономном округе"
#
# Принят Думой Ханты-Мансийского автономного округа - Югры 24 ноября 2004 года...
# --------------------------------------------------------------------------------
# 13. garant_0290.txt (дистанция: 63.2496)
# ﻿
# Закон Республики Мордовия
# от 25 ноября 2004 г. N 78-З
# "О внесении изменения в Закон Республики Мордовия "О ставках налога
# на игорный бизнес на территории Республики Мордовия"
#
# Принят Государственным Собранием 25 ноября 2004 года
#
# Статья 1. Внести в Закон Республики Мордовия от 27 ноября 2003 г...
# --------------------------------------------------------------------------------
# 14. garant_0557.txt (дистанция: 63.2583)
# ﻿
# Закон Ханты-Мансийского АО - Югры 30 ноября 2004 г. N 66-оз
# "О внесении изменения в Закон Ханты-Мансийского автономного округа
# "О единых ставках налога на игорный бизнес для всех игорных заведений,
# находящихся на территории Ханты-Мансийского автономного округа"
#
# Принят Думой Ханты-Мансийского авт...
# --------------------------------------------------------------------------------
# 15. garant_0985.txt (дистанция: 63.2694)
# ﻿
# Постановление Правительства Нижегородской области
# от 27 декабря 2004 г. N 294
# "О проведении в 2005 году на территории Нижегородской области
# Года ветеранов Великой Отечественной войны - защитников Отечества,
# посвященного 60-летию Победы в Великой Отечественной войне
# 1941-1945 годов"
#
# В связи с подг...
# --------------------------------------------------------------------------------
# 16. garant_0960.txt (дистанция: 63.2721)
# ﻿
# Постановление Правительства Омской области
# от 1 ноября 2004 г. N 77-п
# "О величине прожиточного минимума на душу населения и по основным
# социально-демографическим группам населения в Омской области
# за III квартал 2004 года"
#
#
# В соответствии со статьей 4 Федерального закона "О прожиточном минимуме в...
# --------------------------------------------------------------------------------
# 17. garant_1184.txt (дистанция: 63.2831)
# ﻿
# Решение Главного управления по государственному регулированию цен и тарифов
# администрации Калининградской области от 12 ноября 2004 г. N 1-43/04
# "Об утверждении тарифа на тепловую энергию для ФГУП "Калининградский
# морской рыбный порт"
#
# В соответствии с Федеральным законом от 14 апреля 1995 года N...
# --------------------------------------------------------------------------------
# 18. garant_1208.txt (дистанция: 63.2839)
# ﻿
# Постановление администрации Калининградской области
# от 15 ноября 2004 г. N 506
# "Об установлении величины прожиточного минимума на душу населения
# и по основным социально-демографическим группам населения
# в Калининградской области за III квартал 2004 года"
#
#
# В соответствии с Федеральным законом "О...
# --------------------------------------------------------------------------------
# 19. garant_0231.txt (дистанция: 63.3103)
# ﻿
# Постановление Правительства Кировской области
# от 19 октября 2004 г. N 18/229
# "Об организации проведения конкурса
# "Организация высокой социальной эффективности"
# среди организаций области"
#
# Правительство Кировской области постановляет:
# 1. В соответствии с Планом совместных мероприятий Вятской торгов...
# --------------------------------------------------------------------------------
# 20. garant_0188.txt (дистанция: 63.3137)
# ﻿Закон г. Москвы от 20 октября 2004 г. № 63
# “О внесении изменений  в Закон города Москвы от 5 марта 2003 года № 12 “Об установлении ставки налога на прибыль для общественных организаций инвалидов и организаций, использующих труд инвалидов”
#
# Статья 1. О внесении изменений в Закон
# В соответствии с Фед...
# --------------------------------------------------------------------------------
