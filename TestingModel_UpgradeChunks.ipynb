# %%
import os
import faiss
import numpy as np
from sentence_transformers import SentenceTransformer

# %% [markdown]
# ## Указать все пути
# MODEL_NAME - путь к предобученной модели (уже указан)
# TEXT_FILES_DIR - путь к директории с текстами
# FAISS_INDEX_PATH - путь для сохранения/загрузки FAISS-индекса
# FILENAMES_PATH - путь для сохранения/загрузки списка имен файлов

# %%
MODEL_NAME = "sentence-transformers/paraphrase-multilingual-MiniLM-L12-v2"
TEXT_FILES_DIR = "garant"
FAISS_INDEX_PATH = "results_BERT_UpgradeChunks/text_index.faiss"
FILENAMES_PATH = "results_BERT_UpgradeChunks/filenames.npy"

# %%
model = SentenceTransformer(MODEL_NAME)
index = faiss.read_index(FAISS_INDEX_PATH)
filenames = np.load(FILENAMES_PATH, allow_pickle=True)

# %% [markdown]
# ## Функция разбиения длинных текстов на чанки

# %%
def split_text_by_length(text, max_length=1000):
    words = text.split()
    chunks = []
    current_chunk = ""
    for word in words:
        if len(current_chunk) + len(word) + 1 <= max_length:
            current_chunk = current_chunk + " " + word if current_chunk else word
        else:
            chunks.append(current_chunk)
            current_chunk = word
    if current_chunk:
        chunks.append(current_chunk)
    return chunks

# %% [markdown]
# ## Функция для вычисления эмбеддинга с учётом разбиения длинного текста

# %%
def get_document_embedding(text, model, chunk_size=1000):
    if len(text) <= chunk_size:
        return model.encode(text)
    else:
        chunks = split_text_by_length(text, max_length=chunk_size)
        chunk_embeddings = model.encode(chunks, convert_to_numpy=True)
        return np.mean(chunk_embeddings, axis=0)

# %% [markdown]
# ## Функция поиска похожих текстов по входному файлу текста

# %%
def find_similar_texts_from_file(file_path, top_k=5):
    with open(file_path, "r", encoding="utf-8") as f:
        query_text = f.read().strip()

    query_embedding = get_document_embedding(query_text, model, chunk_size=1000)
    distances, indices = index.search(np.array([query_embedding]).astype('float32'), top_k)

    print("Наиболее похожие тексты:")
    for i, idx in enumerate(indices[0]):
        text_filename = filenames[idx]
        similarity = max(0, (1 - distances[0][i] / 2)) * 100 # пересчёт L2-дистанции в процент схожести
        print(f"{i+1}. {text_filename} (схожесть: {similarity:.2f}%)")

        found_file_path = os.path.join(TEXT_FILES_DIR, text_filename) # загружаем и выводим первые 300 символов найденного текста
        if os.path.exists(found_file_path):
            with open(found_file_path, "r", encoding="utf-8") as f:
                preview_text = f.read(300)
            print(preview_text + "...")
        else:
            print("[Файл не найден в папке]")
        
        print("-" * 80)

# %% [markdown]
# ## Тестирование
# file_path - путь к текстовому файлу, который будет поступать на вход

# %%
file_path = "garant.txt"

# %%
find_similar_texts_from_file(file_path, top_k=20)
# Out:
# Наиболее похожие тексты:
# 1. garant_1261.txt (схожесть: 100.00%)
# ﻿
# Постановление Мэра г. Хабаровска
# от 11 ноября 2004 г. N 1650
# "О проведении Международного дня инвалидов в городе Хабаровске в 2004 году"
#
# В связи с проведением 3 декабря 2004 года Международного дня инвалидов и в целях привлечения внимания широких слоев общественности города, предприятий, учрежден...
# --------------------------------------------------------------------------------
# 2. garant_0592.txt (схожесть: 40.18%)
# ﻿
# Решение Челябинской городской Думы от 7 декабря 2004 г. N 41/11
# "О принятии городской целевой программы "О праздновании 60-й годовщины
# Победы в Великой Отечественной войне 1941-1945 годов в городе Челябинске"
#
# В связи с 60-летием со дня Победы советского народа в Великой Отечественной войне 1941...
# --------------------------------------------------------------------------------
# 3. garant_0718.txt (схожесть: 21.25%)
# ﻿
# --------------------------------------------------------------------------------
# 12. garant_1340.txt (схожесть: 1.16%)
# ﻿
# Закон Ярославской области от 7 декабря 2004 г. N 58-з
# "Об утверждении областной целевой программы
# "Комплексные меры противодействия злоупотреблению
# наркотиками и их незаконному обороту на период
# с 2005 по 2007 год"
#
# Принят Государственной Думой Ярославской области 23 ноября 2004 года
#
# Статья 1
# 1. ...
# --------------------------------------------------------------------------------
# 13. garant_0162.txt (схожесть: 0.36%)
# ﻿
# Решение Городской думы г. Ижевска от 21 октября 2004 г. N 259
# "Об утверждении Городской программы профилактики
# наркомании, токсикомании, алкоголизма и их социальных
# последствий на 2005-2007 годы"
#
# С целью ограничения распространения наркомании, алкоголизма, токсикомании и связанных с ними негативн...
# --------------------------------------------------------------------------------
# 14. garant_0924.txt (схожесть: 0.36%)
# ﻿
# Решение Городской думы г. Ижевска от 21 октября 2004 г. N 259
# "Об утверждении Городской программы профилактики
# наркомании, токсикомании, алкоголизма и их социальных
# последствий на 2005-2007 годы"
#
# С целью ограничения распространения наркомании, алкоголизма, токсикомании и связанных с ними негативн...
# --------------------------------------------------------------------------------
# 15. garant_0078.txt (схожесть: 0.21%)
# ﻿
# Постановление Мэра г. Хабаровска
# от 12 ноября 2004 г. N 1662
# "О городском смотре-конкурсе на лучшую организацию органами студенческого
# (ученического) самоуправления социально-значимого досуга в общежитиях
# учебных заведений города"
#
# В соответствии с основными направлениями реализации Городской ко...
# --------------------------------------------------------------------------------
# 16. garant_0456.txt (схожесть: 0.00%)
# ﻿
# Решение Челябинской городской Думы от 28 декабря 2004 г. N 42/9
# "О принятии городской целевой программы "О мерах по обеспечению
# безопасности в муниципальных учреждениях культуры города Челябинска" на
# 2005-2007 годы"
#
# В соответствии с Федеральным законом от 28 августа 1995г. N 154-ФЗ "Об общих при...
# --------------------------------------------------------------------------------
# 17. garant_0261.txt (схожесть: 0.00%)
# ﻿
# Решение Сургутской районной Думы от 3 декабря 2004 г. N 269
# "Об утверждении районной целевой программы
# "Комплексные меры противодействия злоупотреблению наркотиками и их незаконному обороту
# на 2004-2005 годы"
#
# Рассмотрев проект районной целевой программы "Комплексные меры противодействия злоупот...
# --------------------------------------------------------------------------------
# 18. garant_0715.txt (схожесть: 0.00%)
# ﻿
# Решение Сургутской районной Думы от 3 декабря 2004 г. N 269
# "Об утверждении районной целевой программы
# "Комплексные меры противодействия злоупотреблению наркотиками и их незаконному обороту
# на 2004-2005 годы"
#
# Рассмотрев проект районной целевой программы "Комплексные меры противодействия злоупот...
# --------------------------------------------------------------------------------
# 19. garant_1175.txt (схожесть: 0.00%)
# ﻿
# Постановление Правительства Саратовской области
# от 27 мая 2004 г. N 126-П
# "О проекте Программы "Безопасность образовательных учреждений
# Саратовской области на 2005-2007 годы"
#
# Во исполнение Федерального закона "О пожарной безопасности", с учетом решения Правительственной комиссии по предупреждению...
# --------------------------------------------------------------------------------
# 20. garant_1069.txt (схожесть: 0.00%)
# ﻿
# Постановление Администрации Тамбовской области
# от 8 декабря 2004 г. N 983
# "О проведении в 2005 году эксперимента по введению единого
# государственного экзамена на территории Тамбовской области"
#
# Во исполнение постановлений Правительства Российской Федерации от 16.02.2001 N 119 "Об организации экспе...
# --------------------------------------------------------------------------------
