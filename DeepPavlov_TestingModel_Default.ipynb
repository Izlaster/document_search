# %%
import os
import faiss
import shutil
import numpy as np
from sentence_transformers import SentenceTransformer

# %% [markdown]
# ## Указать все пути
# MODEL_NAME - путь к предобученной модели (уже указан)
# TEXT_FILES_DIR - путь к директории с текстами
# FAISS_INDEX_PATH - путь для сохранения/загрузки FAISS-индекса
# FILENAMES_PATH - путь для сохранения/загрузки списка имен файлов
# VECTORS_PATH - путь к папке с векторами

# %%
MODEL_NAME = "DeepPavlov/rubert-base-cased"
TEXT_FILES_DIR = "garant"
FAISS_INDEX_PATH = "results_DeepPavlov_Default/text_index.faiss"
FILENAMES_PATH = "results_DeepPavlov_Default/filenames.npy"
VECTORS_PATH = "results_DeepPavlov_Default/vectors"

# %%
model = SentenceTransformer(MODEL_NAME)
index = faiss.read_index(FAISS_INDEX_PATH)
filenames = np.load(FILENAMES_PATH, allow_pickle=True)
# Out:
# No sentence-transformers model found with name DeepPavlov/rubert-base-cased. Creating a new one with mean pooling.
# Some weights of the model checkpoint at DeepPavlov/rubert-base-cased were not used when initializing BertModel: ['cls.predictions.bias', 'cls.predictions.decoder.bias', 'cls.predictions.decoder.weight', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.dense.bias', 'cls.predictions.transform.dense.weight', 'cls.seq_relationship.bias', 'cls.seq_relationship.weight']
# - This IS expected if you are initializing BertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# model.safetensors:   0%|          | 0.00/714M [00:00<?, ?B/s]

# %% [markdown]
# ## Функция разбиения длинных текстов на чанки

# %%
def split_text_by_length(text, max_length=1000):
    words = text.split()
    chunks = []
    current_chunk = ""
    for word in words:
        if len(current_chunk) + len(word) + 1 <= max_length:
            current_chunk = current_chunk + " " + word if current_chunk else word
        else:
            chunks.append(current_chunk)
            current_chunk = word
    if current_chunk:
        chunks.append(current_chunk)
    return chunks

# %% [markdown]
# ## Функция для вычисления эмбеддинга с учётом разбиения длинного текста

# %%
def get_document_embedding(text, model, chunk_size=1000):
    if len(text) <= chunk_size:
        return model.encode(text)
    else:
        chunks = split_text_by_length(text, max_length=chunk_size)
        chunk_embeddings = model.encode(chunks, convert_to_numpy=True)
        return np.mean(chunk_embeddings, axis=0)

# %% [markdown]
# ## Функция поиска похожих текстов

# %%
def find_similar_texts_from_file(file_path, top_k=5):
    os.makedirs(VECTORS_PATH, exist_ok=True)
    
    with open(file_path, "r", encoding="utf-8") as f:
        query_text = f.read().strip()
    
    query_embedding = model.encode([query_text], convert_to_numpy=True)
    query_embedding = query_embedding / np.linalg.norm(query_embedding, axis=1, keepdims=True)
    
    base_filename = os.path.splitext(os.path.basename(file_path))[0]  # Убираем расширение
    vector_file_path = os.path.join(VECTORS_PATH, base_filename + ".txt")
    np.savetxt(vector_file_path, query_embedding, delimiter=",", fmt="%.6f")
    
    distances, indices = index.search(query_embedding.astype('float32'), top_k)
    
    print("Наиболее похожие тексты:")
    for i, idx in enumerate(indices[0]):
        text_filename = filenames[idx]
        similarity = max(0, (1 - distances[0][i] / 2)) * 100
        
        found_file_path = os.path.join(TEXT_FILES_DIR, text_filename)
        base_text_filename = os.path.splitext(text_filename)[0]  # Убираем расширение
        vector_output_path = os.path.join(VECTORS_PATH, base_text_filename + ".txt")
        
        if os.path.exists(found_file_path):
            with open(found_file_path, "r", encoding="utf-8") as f:
                full_text = f.read()
            
            text_embedding = model.encode([full_text], convert_to_numpy=True)
            text_embedding = text_embedding / np.linalg.norm(text_embedding, axis=1, keepdims=True)
            np.savetxt(vector_output_path, text_embedding, delimiter=",", fmt="%.6f")
            
            print(f"{i+1}. {text_filename} (схожесть: {similarity:.2f}%)")
            print(full_text[:300] + "...")
        else:
            print(f"{i+1}. {text_filename} [Файл не найден]")
        
        print("-" * 80)

# %% [markdown]
# ## Очистка

# %%
def clear_vectors_path():
    if not os.path.exists(VECTORS_PATH):
        print(f"Путь {VECTORS_PATH} не существует.")
        return

    for entry in os.listdir(VECTORS_PATH):
        entry_path = os.path.join(VECTORS_PATH, entry)
        try:
            if os.path.isfile(entry_path) or os.path.islink(entry_path):
                os.remove(entry_path)
            elif os.path.isdir(entry_path):
                shutil.rmtree(entry_path)
        except Exception as e:
            print(f"Не удалось удалить {entry_path}: {e}")
            
clear_vectors_path()

# %% [markdown]
# ## Тестирование
# file_path - путь к текстовому файлу, который будет поступать на вход

# %%
file_path = "garant.txt"

# %%
find_similar_texts_from_file(file_path, top_k=20)
# Out:
# Наиболее похожие тексты:
# 1. garant_1261.txt (схожесть: 100.00%)
# ﻿
# Постановление Мэра г. Хабаровска
# от 11 ноября 2004 г. N 1650
# "О проведении Международного дня инвалидов в городе Хабаровске в 2004 году"
#
# В связи с проведением 3 декабря 2004 года Международного дня инвалидов и в целях привлечения внимания широких слоев общественности города, предприятий, учрежден...
# --------------------------------------------------------------------------------
# 2. garant_1021.txt (схожесть: 92.66%)
# ﻿
# Постановление Главы администрации г.Чебоксары Чувашской Республики
# от 4 ноября 2004 г. N 191
# "Об утверждении Правил содержания животных в городе Чебоксары"
#
# В целях профилактики зооантропонозных инфекционных заболеваний, упорядочения содержания домашних животных в городе Чебоксары и во исполнение ...
# --------------------------------------------------------------------------------
# 3. garant_0997.txt (схожесть: 92.22%)
# ﻿
# Постановление Главы города Челябинска
# от 17 ноября 2004 г. N 2078-п
# "О вручении единовременных стипендий Администрации города Челябинска
# студентам и аспирантам высших учебных заведений города"
#
# В целях поддержки молодежи высших учебных заведений за особые успехи в учебе, научной и общественной...
# --------------------------------------------------------------------------------
# 4. garant_0078.txt (схожесть: 91.95%)
# ﻿
# Постановление Мэра г. Хабаровска
# от 12 ноября 2004 г. N 1662
# "О городском смотре-конкурсе на лучшую организацию органами студенческого
# (ученического) самоуправления социально-значимого досуга в общежитиях
# учебных заведений города"
#
# В соответствии с основными направлениями реализации Городской ко...
# --------------------------------------------------------------------------------
# 5. garant_1022.txt (схожесть: 91.90%)
# ﻿
# Постановление Главы администрации муниципального образования г. Владивосток от 14 октября 2004 г. N 183
# "О начале отопительного сезона 2004-2005 гг. в муниципальном образовании г. Владивосток"
#
# Руководствуясь Уставом г. Владивостока, Федеральным законом "Об общих принципах организации местного сам...
# --------------------------------------------------------------------------------
# 6. garant_0702.txt (схожесть: 91.83%)
# ﻿
# Распоряжение Мэра г.Сургута от 26 ноября 2004 г. N 4436
# "О проведении творческого конкурса среди средств массовой информации
# и журналистов, посвященного 60-летию со Дня Победы
# в Великой Отечественной войне 1941-1945 гг."
#
# В рамках подготовки к празднованию 60-летия со Дня Победы в Великой Отечес...
# --------------------------------------------------------------------------------
# 7. garant_0140.txt (схожесть: 91.77%)
# ﻿     Распоряжение Правительства Москвы от 19 января 2005 г. N 33-РП
#  "О мероприятиях, посвященных 250-летию основания МГУ им.М.В.Ломоносова
#       и празднику студентов "Татьянин день" 25-26 января 2005 года"
#
#      Во исполнение Закона города Москвы от 22.09.2004 № 56 "О  праздниках
# города Москвы", ...
# --------------------------------------------------------------------------------
# 8. garant_0522.txt (схожесть: 91.71%)
# ﻿
# Постановление Мэра г. Хабаровска
# от 1 декабря 2004 г. N 1762
# "О проведении в 2005 году творческого конкурса средств массовой
# информации г. Хабаровска, посвященного 60-летию Победы в Великой
# Отечественной войне"
#
# В ознаменование предстоящего 9 мая 2005 года 60-летия Победы советского народа в Велик...
# --------------------------------------------------------------------------------
# 9. garant_1425.txt (схожесть: 91.59%)
# ﻿
# Постановление Главы города Челябинска
# от 8 июня 2004 г. N 991-п
# "Об утверждении "Программы мероприятий, обеспечивающих доступ инвалидов и
# маломобильных групп населения в существующие здания общественного
# назначения"
#
# В целях реализации постановления Главы города от 18.02.2003г. N 240-п "О бесп...
# --------------------------------------------------------------------------------
# 10. garant_0850.txt (схожесть: 91.48%)
# ﻿
# Постановление мэра города Саратова от 15 декабря 2004 г. N 607
# "Об обеспечении в городе Саратове пожарной безопасности
# в осенне-зимний пожароопасный период"
#
# Во исполнение Федерального закона от 21 декабря 1994 года N 69-ФЗ "О пожарной безопасности", а также для создания условий, обеспечивающих на...
# --------------------------------------------------------------------------------
# 11. garant_0422.txt (схожесть: 91.37%)
# ﻿
# Постановление Главы администрации г.Казани
# от 9 декабря 2004 г. N 1982
# "Об упорядочении рыночной торговли и утверждении
# Правил работы рынков в г.Казани"
#
# Во исполнение решения Казанского Совета народных депутатов от 26.12.2004 N 12-18 "О Программе развития рынка потребительских услуг г.Казани на 2...
# --------------------------------------------------------------------------------
# 12. garant_2063.txt (схожесть: 91.34%)
# ﻿
# Постановление Мэра г. Хабаровска
# от 13 сентября 2004 г. N 1370/1
# "О проведении мероприятий по призыву граждан призывных возрастов на
# военную службу осенью 2004 года и обеспечении этих мероприятий"
#
# В соответствии с Законом Российской Федерации от 28.03.98 N 53-ФЗ "О воинской обязанности и военной ...
# --------------------------------------------------------------------------------
# 13. garant_0426.txt (схожесть: 91.10%)
# ﻿
# Постановление Губернатора Ярославской области
# от 7 декабря 2004 г. N 814
# "О поддержке одаренных детей Ярославской области"
#
# В соответствии с Законом Ярославской области от 12 июля 2004 года N 24-з "О поддержке одаренных детей", постановлением Администрации области от 29.10.2003 N 155-а "Об областн...
# --------------------------------------------------------------------------------
# 14. garant_1341.txt (схожесть: 91.10%)
# ﻿
# Постановление Губернатора Ярославской области
# от 7 декабря 2004 г. N 814
# "О поддержке одаренных детей Ярославской области"
#
# В соответствии с Законом Ярославской области от 12 июля 2004 года N 24-з "О поддержке одаренных детей", постановлением Администрации области от 29.10.2003 N 155-а "Об областн...
# --------------------------------------------------------------------------------
# 15. garant_0593.txt (схожесть: 90.91%)
# ﻿
# Постановление Губернатора Хабаровского края
# от 6 сентября 2004 г. N 231
# "О дополнительных мерах по предупреждению проявлений террористической
# направленности и повышению бдительности на территории Хабаровского края"
#
# В связи с совершением ряда террористических актов в городах Российской Федерации, ...
# --------------------------------------------------------------------------------
# 16. garant_1867.txt (схожесть: 90.89%)
# ﻿
# Постановление Главы администрации г.Казани
# от 30 сентября 2004 г. N 1617
# "О Реестре объектов рынка потребительских услуг г.Казани"
#
# В соответствии с Федеральным законом "О защите прав потребителей" и во исполнение постановления Главы администрации г.Казани от 05.02.2004 N 136 "О плане мероприятий ...
# --------------------------------------------------------------------------------
# 17. garant_0991.txt (схожесть: 90.88%)
# ﻿
# Распоряжение главы администрации города Нижнего Новгорода
# от 1 октября 2004 г. N 3231-р
# "О проведении открытых конкурсов на размещение муниципального заказа
# по содержанию и ремонту дорог и дорожных сооружений районов
# города Нижнего Новгорода"
#
# В целях обеспечения эффективного расходования средств ...
# --------------------------------------------------------------------------------
# 18. garant_0038.txt (схожесть: 90.87%)
# ﻿
# Постановление Мэра г. Калининграда от 13 января 2005 г. N 7
# "О лимитах потребления энергоресурсов организациями, финансируемыми
# из городского бюджета на 2005 год"
#
# В целях устойчивого обеспечения энергоресурсами организаций, финансируемых из городского бюджета, упорядочения расходов по оплате за ...
# --------------------------------------------------------------------------------
# 19. garant_0722.txt (схожесть: 90.87%)
# ﻿
# Постановление Мэра г. Калининграда от 13 января 2005 г. N 7
# "О лимитах потребления энергоресурсов организациями, финансируемыми
# из городского бюджета на 2005 год"
#
# В целях устойчивого обеспечения энергоресурсами организаций, финансируемых из городского бюджета, упорядочения расходов по оплате за ...
# --------------------------------------------------------------------------------
# 20. garant_0192.txt (схожесть: 90.67%)
# ﻿
# Постановление Мэра г. Калининграда от 27 декабря 2004 г. N 3673
# "Об исполнении функций заказчика по уборке общегородских территорий,
# текущему содержанию и капитальному ремонту объектов благоустройства"
#
# Во исполнение решения городского Совета депутатов Калининграда от 23 июня 2004 года N 186 "Об у...
# --------------------------------------------------------------------------------
