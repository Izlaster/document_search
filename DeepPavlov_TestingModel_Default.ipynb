# %%
import os
import faiss
import numpy as np
from sentence_transformers import SentenceTransformer

# %% [markdown]
# ## Указать все пути
# MODEL_NAME - путь к предобученной модели (уже указан)
# TEXT_FILES_DIR - путь к директории с текстами
# FAISS_INDEX_PATH - путь для сохранения/загрузки FAISS-индекса
# FILENAMES_PATH - путь для сохранения/загрузки списка имен файлов
# VECTORS_PATH - путь к папке с векторами

# %%
MODEL_NAME = "DeepPavlov/rubert-base-cased"
TEXT_FILES_DIR = "garant"
FAISS_INDEX_PATH = "results_DeepPavlov_Default/text_index.faiss"
FILENAMES_PATH = "results_DeepPavlov_Default/filenames.npy"
VECTORS_PATH = "results_DeepPavlov_Default/vectors"

# %%
model = SentenceTransformer(MODEL_NAME)
index = faiss.read_index(FAISS_INDEX_PATH)
filenames = np.load(FILENAMES_PATH, allow_pickle=True)

# %% [markdown]
# ## Функция разбиения длинных текстов на чанки

# %%
def split_text_by_length(text, max_length=1000):
    words = text.split()
    chunks = []
    current_chunk = ""
    for word in words:
        if len(current_chunk) + len(word) + 1 <= max_length:
            current_chunk = current_chunk + " " + word if current_chunk else word
        else:
            chunks.append(current_chunk)
            current_chunk = word
    if current_chunk:
        chunks.append(current_chunk)
    return chunks

# %% [markdown]
# ## Функция для вычисления эмбеддинга с учётом разбиения длинного текста

# %%
def get_document_embedding(text, model, chunk_size=1000):
    if len(text) <= chunk_size:
        return model.encode(text)
    else:
        chunks = split_text_by_length(text, max_length=chunk_size)
        chunk_embeddings = model.encode(chunks, convert_to_numpy=True)
        return np.mean(chunk_embeddings, axis=0)

# %% [markdown]
# ## Функция поиска похожих текстов

# %%
def find_similar_texts_from_file(file_path, top_k=5):
    os.makedirs(VECTORS_PATH, exist_ok=True)
    with open(file_path, "r", encoding="utf-8") as f:
        query_text = f.read().strip()

    query_embedding = model.encode([query_text], convert_to_numpy=True)
    query_embedding = query_embedding / np.linalg.norm(query_embedding, axis=1, keepdims=True)

    distances, indices = index.search(query_embedding.astype('float32'), top_k)

    print("Наиболее похожие тексты:")
    for i, idx in enumerate(indices[0]):
        text_filename = filenames[idx]
        similarity = max(0, (1 - distances[0][i] / 2)) * 100
        
        found_file_path = os.path.join(TEXT_FILES_DIR, text_filename)
        output_file_path = os.path.join(VECTORS_PATH, text_filename)
        
        if os.path.exists(found_file_path):
            with open(found_file_path, "r", encoding="utf-8") as f:
                full_text = f.read()
            
            with open(output_file_path, "w", encoding="utf-8") as out_f:
                out_f.write(full_text)
            
            print(f"{i+1}. {text_filename} (схожесть: {similarity:.2f}%)")
            print(full_text[:300] + "...")
        else:
            print(f"{i+1}. {text_filename} [Файл не найден]")
        
        print("-" * 80)

# %% [markdown]
# ## Тестирование
# file_path - путь к текстовому файлу, который будет поступать на вход

# %%
file_path = "garant.txt"

# %%
find_similar_texts_from_file(file_path, top_k=20)
# Out:
# Наиболее похожие тексты:
# 1. garant_1261.txt (схожесть: 100.00%)
# ﻿
# Постановление Мэра г. Хабаровска
# от 11 ноября 2004 г. N 1650
# "О проведении Международного дня инвалидов в городе Хабаровске в 2004 году"
#
# В связи с проведением 3 декабря 2004 года Международного дня инвалидов и в целях привлечения внимания широких слоев общественности города, предприятий, учрежден...
# --------------------------------------------------------------------------------
# 2. garant_0997.txt (схожесть: 90.74%)
# ﻿
# Постановление Главы города Челябинска
# от 17 ноября 2004 г. N 2078-п
# "О вручении единовременных стипендий Администрации города Челябинска
# студентам и аспирантам высших учебных заведений города"
#
# В целях поддержки молодежи высших учебных заведений за особые успехи в учебе, научной и общественной...
# --------------------------------------------------------------------------------
# 3. garant_0078.txt (схожесть: 90.66%)
# ﻿
# Постановление Мэра г. Хабаровска
# от 12 ноября 2004 г. N 1662
# "О городском смотре-конкурсе на лучшую организацию органами студенческого
# (ученического) самоуправления социально-значимого досуга в общежитиях
# учебных заведений города"
#
# В соответствии с основными направлениями реализации Городской ко...
# --------------------------------------------------------------------------------
# 4. garant_0140.txt (схожесть: 89.19%)
# ﻿     Распоряжение Правительства Москвы от 19 января 2005 г. N 33-РП
#  "О мероприятиях, посвященных 250-летию основания МГУ им.М.В.Ломоносова
#       и празднику студентов "Татьянин день" 25-26 января 2005 года"
#
#      Во исполнение Закона города Москвы от 22.09.2004 № 56 "О  праздниках
# города Москвы", ...
# --------------------------------------------------------------------------------
# 5. garant_0234.txt (схожесть: 88.54%)
# ﻿
# Распоряжение Правительства Кировской области
# от 24 ноября 2004 г. N 400
# "О проведении регионального финала XIV Международного конкурса
# "Серебряная нить - 2005"
#
# В целях повышения профессионального мастерства студентов, преподавателей и молодых специалистов сферы швейной промышленности и индустрии ...
# --------------------------------------------------------------------------------
# 6. garant_1338.txt (схожесть: 88.20%)
# ﻿
# Постановление Губернатора Ярославской области
# от 30 ноября 2004 г. N 800
# "О дополнительных мерах социальной поддержки участников и
# инвалидов Великой Отечественной войны в 2005 году"
#
# В целях социальной поддержки участников и инвалидов Великой Отечественной войны в год 60-летия Победы постановляю:
# ...
# --------------------------------------------------------------------------------
# 7. garant_0903.txt (схожесть: 87.60%)
# ﻿
# Приказ Главного организационно-кадрового управления Омской области
# от 9 сентября 2004 г. N 1-п
# "О грантах Губернатора Омской области в 2004 году"
#
# В соответствии с пунктом 2 Указа Губернатора Омской области от 2 августа 2004 года N 165 "О грантах Губернатора Омской области для поддержки общественн...
# --------------------------------------------------------------------------------
# 8. garant_0322.txt (схожесть: 87.36%)
# ﻿
# Решение Сургутской районной Думы от 24 декабря 2004 г. N 298
# "Об утверждении районной целевой программы
# "Комплексные мероприятия по социальной поддержке ветеранов боевых
# действий на 2005-2007 годы в Сургутском районе"
#
# В целях комплексного решения проблем социальной поддержки ветеранов войны в А...
# --------------------------------------------------------------------------------
# 9. garant_1303.txt (схожесть: 87.36%)
# ﻿
# Решение Сургутской районной Думы от 24 декабря 2004 г. N 298
# "Об утверждении районной целевой программы
# "Комплексные мероприятия по социальной поддержке ветеранов боевых
# действий на 2005-2007 годы в Сургутском районе"
#
# В целях комплексного решения проблем социальной поддержки ветеранов войны в А...
# --------------------------------------------------------------------------------
# 10. garant_0781.txt (схожесть: 87.26%)
# ﻿
# Распоряжение Администрации Приморского края от 23 декабря 2004 г. N 701-р
# "О распределении средств федерального бюджета"
#
# Во исполнение статьи 47 Федерального закона от 23 декабря 2003 года N 186-ФЗ "О федеральном бюджете на 2004 год", на основании статьи 62 Устава Приморского края, в соответствии...
# --------------------------------------------------------------------------------
# 11. garant_1780.txt (схожесть: 87.24%)
# ﻿
# Постановление Правительства Свердловской области
# от 1 ноября 2004 г. N 1030-ПП
# "О поддержке развития молодежных жилищно-строительных
# кооперативов"
#
# Во исполнение постановления Правительства Свердловской области от 06.06.2001 г. N 393-ПП "О Концепции "Сбережение населения Свердловской области на п...
# --------------------------------------------------------------------------------
# 12. garant_0592.txt (схожесть: 86.95%)
# ﻿
# Решение Челябинской городской Думы от 7 декабря 2004 г. N 41/11
# "О принятии городской целевой программы "О праздновании 60-й годовщины
# Победы в Великой Отечественной войне 1941-1945 годов в городе Челябинске"
#
# В связи с 60-летием со дня Победы советского народа в Великой Отечественной войне 1941...
# --------------------------------------------------------------------------------
# 13. garant_0682.txt (схожесть: 86.90%)
# ﻿
# Решение Омского городского Совета
# от 21 июля 2004 г. N 197
# "Об установлении доплаты отдельным категориям граждан,
# имеющих почетные звания СССР, РСФСР и Российской Федерации"
#
# Учитывая значительный вклад отдельных категорий специалистов в развитие образования, культуры, здравоохранения, физической ...
# --------------------------------------------------------------------------------
# 14. garant_0111.txt (схожесть: 86.81%)
# ﻿
# Постановление Правительства Ханты-Мансийского АО - Югры от 25 ноября 2004 г. N 454-п
# "О выплате единовременной материальной помощи неработающим пенсионерам,
# проживающим на территории автономного округа"
#
# В целях реализации постановления Губернатора автономного округа от 18 июня 2002 года N 101 "О ...
# --------------------------------------------------------------------------------
# 15. garant_1620.txt (схожесть: 86.53%)
# ﻿
# Закон
# Самарской области
# от 13 октября 2004 г. N 132-ГД
# "О внесении изменений в Закон Самарской области "О порядке
# предоставления работникам организаций бюджетной сферы,
# государственным и муниципальным служащим Самарской области,
# нуждающимся в улучшении жилищных условий, субсидий на
# строительство и...
# --------------------------------------------------------------------------------
# 16. garant_0702.txt (схожесть: 86.51%)
# ﻿
# Распоряжение Мэра г.Сургута от 26 ноября 2004 г. N 4436
# "О проведении творческого конкурса среди средств массовой информации
# и журналистов, посвященного 60-летию со Дня Победы
# в Великой Отечественной войне 1941-1945 гг."
#
# В рамках подготовки к празднованию 60-летия со Дня Победы в Великой Отечес...
# --------------------------------------------------------------------------------
# 17. garant_0426.txt (схожесть: 86.39%)
# ﻿
# Постановление Губернатора Ярославской области
# от 7 декабря 2004 г. N 814
# "О поддержке одаренных детей Ярославской области"
#
# В соответствии с Законом Ярославской области от 12 июля 2004 года N 24-з "О поддержке одаренных детей", постановлением Администрации области от 29.10.2003 N 155-а "Об областн...
# --------------------------------------------------------------------------------
# 18. garant_1341.txt (схожесть: 86.39%)
# ﻿
# Постановление Губернатора Ярославской области
# от 7 декабря 2004 г. N 814
# "О поддержке одаренных детей Ярославской области"
#
# В соответствии с Законом Ярославской области от 12 июля 2004 года N 24-з "О поддержке одаренных детей", постановлением Администрации области от 29.10.2003 N 155-а "Об областн...
# --------------------------------------------------------------------------------
# 19. garant_0503.txt (схожесть: 86.36%)
# ﻿
# Постановление Администрации Тюменской области от 6 декабря 2004 г. N 163-пк
# "О мерах социальной поддержки, осуществляемых путем возмещения расходов
# на оплату проезда на городском транспорте, автомобильном транспорте
# пригородного и междугороднего сообщения, а также железнодорожном
# транспорте, в 200...
# --------------------------------------------------------------------------------
# 20. garant_1104.txt (схожесть: 86.12%)
# ﻿
# Закон Приморского края от 29 декабря 2004 г. N 206-КЗ
# "О социальной поддержке льготных категорий граждан, проживающих
# на территории Приморского края"
#
# Принят Законодательным Собранием Приморского края 22 декабря 2004 года
#
# Настоящий Закон устанавливает правовые гарантии социальной поддержки ветера...
# --------------------------------------------------------------------------------
