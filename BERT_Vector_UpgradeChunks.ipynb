# %%
import os
import faiss
import numpy as np
from tqdm import tqdm
from sentence_transformers import SentenceTransformer

# %% [markdown]
# ## Этап 1. Загрузка текстов из файлов

# %%
TEXT_FILES_DIR = "garant"

# %%
def load_texts_from_folder(folder_path):
    texts = []
    filenames = []
    for file in tqdm(sorted(os.listdir(folder_path)), desc="Загрузка текстов"):
        if file.endswith(".txt"):
            file_path = os.path.join(folder_path, file)
            with open(file_path, "r", encoding="utf-8") as f:
                text = f.read().strip()
                texts.append(text)
                filenames.append(file)
    return texts, filenames

# %%
texts, filenames = load_texts_from_folder(TEXT_FILES_DIR)
# Out:
# Загрузка текстов: 100%|█████████████████████████████████████████████████████████████| 1628/1628 [00:16<00:00, 96.10it/s]

# %% [markdown]
# ## Этап 2. Определение функций для разбиения и агрегации эмбеддингов

# %%
# Функция для разбиения текста на чанки по количеству символов, не разрывая слова
def split_text_by_length(text, max_length=1000):
    words = text.split()
    chunks = []
    current_chunk = ""
    for word in words:
        # Если добавление слова не превышает лимит, добавляем его
        if len(current_chunk) + len(word) + 1 <= max_length:
            current_chunk = current_chunk + " " + word if current_chunk else word
        else:
            chunks.append(current_chunk)
            current_chunk = word
    if current_chunk:
        chunks.append(current_chunk)
    return chunks

# %% [markdown]
# Если документ длинный, он разбивается на чанки, для каждого чанка вычисляется эмбеддинг, затем эмбеддинги усредняются

# %%
# Функция для вычисления агрегированного эмбеддинга документа
def get_document_embedding(text, model, chunk_size=1000):
    if len(text) <= chunk_size:
        return model.encode(text)
    else:
        chunks = split_text_by_length(text, max_length=chunk_size)
        chunk_embeddings = model.encode(chunks, convert_to_numpy=True)
        return np.mean(chunk_embeddings, axis=0)

# %% [markdown]
# ## Этап 3. Вычисление эмбеддингов документов с учетом разбиения

# %%
MODEL_NAME = "sentence-transformers/paraphrase-multilingual-MiniLM-L12-v2"
model = SentenceTransformer(MODEL_NAME)

# %%
document_embeddings = []
for text in tqdm(texts, desc="Обработка документов"):
    emb = get_document_embedding(text, model, chunk_size=1000)
    document_embeddings.append(emb)
document_embeddings = np.array(document_embeddings)

print(f"\nФорма эмбеддингов: {document_embeddings.shape}")
# Out:
# Обработка документов: 100%|█████████████████████████████████████████████████████████| 1628/1628 [00:52<00:00, 31.23it/s]
# Форма эмбеддингов: (1628, 384)

# %% [markdown]
# ## Этап 4: Создание FAISS-индекса

# %% [markdown]
# FAISS используется для быстрого поиска среди эмбеддингов

# %%
dimension = document_embeddings.shape[1]

# %% [markdown]
# Создаём FAISS-индекс

# %%
index = faiss.IndexFlatL2(dimension)
index.add(document_embeddings.astype('float32'))

# %% [markdown]
# Сохраняем индекс для последующего использования

# %%
faiss.write_index(index, "results_BERT_UpgradeChunks/text_index.faiss")
np.save("results_BERT_UpgradeChunks/filenames.npy", np.array(filenames))  # сохраняем список имён файлов

# %% [markdown]
# ## Этап 5: Функция поиска похожих текстов

# %%
def find_similar_texts(query, top_k=5):
    query_embedding = model.encode([query], convert_to_numpy=True)
    distances, indices = index.search(query_embedding.astype('float32'), top_k)
    
    print("Наиболее похожие тексты:")
    for i, idx in enumerate(indices[0]):
        print(f"{i+1}. {filenames[idx]} (дистанция: {distances[0][i]:.4f})")
        print(texts[idx][:300] + "...") # выводим первые 300 символов для примера
        print("-" * 80)

# %%
query_text = "Международный день инвалидов в Хабаровске"
find_similar_texts(query_text, top_k=20)
# Out:
# Наиболее похожие тексты:
# 1. garant_1261.txt (дистанция: 14.0135)
# ﻿
# Постановление Мэра г. Хабаровска
# от 11 ноября 2004 г. N 1650
# "О проведении Международного дня инвалидов в городе Хабаровске в 2004 году"
#
# В связи с проведением 3 декабря 2004 года Международного дня инвалидов и в целях привлечения внимания широких слоев общественности города, предприятий, учрежден...
# --------------------------------------------------------------------------------
# 2. garant_0055.txt (дистанция: 14.6030)
# ﻿
# Постановление Губернатора Ярославской области
# от 21 декабря 2004 г. N 859
# "О квотировании рабочих мест для трудоустройства инвалидов"
#
# В соответствии с Федеральным законом от 24.11.95 N 181-ФЗ "О социальной защите инвалидов в Российской Федерации" и в целях установления гарантии трудовой занятости...
# --------------------------------------------------------------------------------
# 3. garant_1851.txt (дистанция: 14.8375)
# ﻿
# Решение Казанского Совета народных депутатов
# от 1 октября 2004 г. N 22-20
# "О мерах по поддержке общероссийских
# общественных организаций инвалидов"
#
# Рассмотрев обращение Татарской республиканской организации Всероссийского общества инвалидов - Общество инвалидов Республики Татарстан, принимая во вн...
# --------------------------------------------------------------------------------
# 4. garant_1337.txt (дистанция: 15.1918)
# ﻿
# Постановление Правительства УР от 17 мая 2004 г. N 64
# "О ежегодных денежных компенсациях расходов, связанных с эксплуатацией
# транспортных средств, и транспортных расходов инвалидам"
#
# В соответствии с Федеральными законами "О социальной защите инвалидов в Российской Федерации" и "О ветеранах" Прави...
# --------------------------------------------------------------------------------
# 5. garant_0274.txt (дистанция: 15.3385)
# ﻿
# Распоряжение Мэра г. Калининграда от 9 ноября 2004 г. N 956-р
# "Об утверждении суммы оплаты за содержание в муниципальных стационарных
# учреждениях социального обслуживания престарелых граждан и инвалидов"
#
# В связи с ростом цен на услуги предприятий коммунального хозяйства, энергоносители, медикамен...
# --------------------------------------------------------------------------------
# 6. garant_0061.txt (дистанция: 15.3884)
# ﻿
# Постановление Администрации Ярославской области
# от 22 декабря 2004 г. N 192-а
# "Об утверждении Порядка воспитания и обучения детей-инвалидов
# на дому"
#
# В соответствии с федеральными законами от 24.11.95 N 181-ФЗ "О социальной защите инвалидов в Российской Федерации", от 22.08.2004 N 122-ФЗ "О внесен...
# --------------------------------------------------------------------------------
# 7. garant_0965.txt (дистанция: 15.4951)
# ﻿
# Закон Республики Хакасия
# от 11 ноября 2004 г. N 84
# "О мерах социальной поддержки ветеранов, проживающих
# на территории Республики Хакасия"
# (Принят Верховным Советом Республики Хакасия 27 октября 2004 г.)
#
#
# В соответствии с Федеральным законом от 12 января 1995 года N 5-ФЗ "О ветеранах" настоящий ...
# --------------------------------------------------------------------------------
# 8. garant_1338.txt (дистанция: 15.5942)
# ﻿
# Постановление Губернатора Ярославской области
# от 30 ноября 2004 г. N 800
# "О дополнительных мерах социальной поддержки участников и
# инвалидов Великой Отечественной войны в 2005 году"
#
# В целях социальной поддержки участников и инвалидов Великой Отечественной войны в год 60-летия Победы постановляю:
# ...
# --------------------------------------------------------------------------------
# 9. garant_1794.txt (дистанция: 15.6049)
# ﻿
# Постановление Администрации Смоленской области
# от 9 ноября 2004 г. N 338
# "О ежеквартальных пособиях гражданам, проходившим военную службу
# по призыву и ставшим инвалидами в результате локальных вооруженных
# конфликтов, и членам семей военнослужащих, погибших при прохождении
# срочной службы, на 2005 г...
# --------------------------------------------------------------------------------
# 10. garant_1231.txt (дистанция: 15.6329)
# ﻿
# Постановление Правительства Ленинградской области
# от 23 декабря 2004 г. N 312
# "Об утверждении Положения о порядке обеспечения
# протезно-ортопедической помощью лиц, проработавших в тылу
# в период с 22 июня 1941 года по 9 мая 1945 года не менее шести
# месяцев, исключая период работы на временно оккупир...
# --------------------------------------------------------------------------------
# 11. garant_0184.txt (дистанция: 15.6439)
# ﻿
# Решение муниципалитета г. Ярославля
# от 5 ноября 2004 г. N 52
# "О предоставлении налоговых льгот"
# (принято муниципалитетом города Ярославля 3 ноября 2004 г.)
#
# В соответствии с решением муниципалитета от 02.04.2003 N 232 "Об утверждении Положения о порядке установления льгот по налогам и сборам", учи...
# --------------------------------------------------------------------------------
# 12. garant_1359.txt (дистанция: 15.6668)
# ﻿       Постановление Правительства РФ от 11 октября 2004 г. N 534
#     "Об утверждении Правил выплаты в 2004 году инвалидам, получившим
#      транспортные средства через органы социальной защиты населения,
#    компенсаций страховых премий по договору обязательного страхования
#       гражданской ответст...
# --------------------------------------------------------------------------------
# 13. garant_1118.txt (дистанция: 15.7105)
# ﻿
# Постановление Псковской городской Думы
# от 29 декабря 2004 г. N 349
# "О социальной поддержке пенсионеров, не обладающих правом на региональные
# и федеральные льготы по проезду в городском пассажирском транспорте"
#
# Принято на 32-й сессии Псковской городской Думы 3-го созыва
#
# С целью реализации муницип...
# --------------------------------------------------------------------------------
# 14. garant_0257.txt (дистанция: 15.7692)
# ﻿
# Закон Нижегородской области
# от 29 ноября 2004 г. N 133-З
# "О мерах социальной поддержки ветеранов"
#
#
# Настоящий Закон устанавливает меры социальной поддержки в соответствии с Федеральным законом от 22 августа 2004 года N 122-ФЗ "О внесении изменений в законодательные акты Российской Федерации и приз...
# --------------------------------------------------------------------------------
# 15. garant_1111.txt (дистанция: 15.7921)
# ﻿
# Постановление Кабинета Министров Республики Татарстан
# от 17 декабря 2004 г. N 540
# "О размерах ежемесячных денежных выплат, ежемесячных пособий
# на ребенка, субсидий, установленных Законом Республики Татарстан
# "Об адресной социальной поддержке населения в Республике Татарстан"
#
# В соответствии с Зако...
# --------------------------------------------------------------------------------
# 16. garant_0468.txt (дистанция: 15.8677)
# ﻿
# Постановление Главы города Лермонтова
# от 26 ноября 2004 г. N 451
# "О квотировании рабочих мест для инвалидов на предприятиях,
# организациях и учреждениях города Лермонтова"
#
# В соответствии с Федеральным законом "О социальной защите инвалидов в Российской Федерации, законом Российской Федерации "О за...
# --------------------------------------------------------------------------------
# 17. garant_0458.txt (дистанция: 15.8858)
# ﻿
# Закон Тверской области от 29 декабря 2004 г. N 84-ЗО
# "О мерах социальной поддержки ветеранов труда, лиц, проработавших
# в тылу в период с 22 июня 1941 года по 9 мая 1945 года не менее
# шести месяцев, исключая период работы на временно оккупированных
# территориях СССР, либо награжденных орденами или м...
# --------------------------------------------------------------------------------
# 18. garant_1108.txt (дистанция: 15.9499)
# ﻿
# Постановление Кабинета Министров Республики Татарстан
# от 17 декабря 2004 г. N 541
# "О государственной социальной помощи в Республике Татарстан"
#
# В целях оказания социальной поддержки и повышения уровня жизни населения Республики Татарстан Кабинет Министров Республики Татарстан постановляет:
# 1. Утве...
# --------------------------------------------------------------------------------
# 19. garant_1220.txt (дистанция: 15.9781)
# ﻿
# Закон Иркутской области от 7 октября 2004 г. N 50-ОЗ
# "О социальной поддержке отдельных групп населения в оказании
# медико-социальной помощи в Иркутской области"
#
# Принят Постановлением Законодательного собрания Иркутской области от 22 сентября 2004 г. N 40/12а-ЗС
#
#               населения            ...
# --------------------------------------------------------------------------------
# 20. garant_1278.txt (дистанция: 16.0150)
# ﻿
# Закон Челябинской области
# от 30 ноября 2004 г. N 327-ЗО
# "О мерах социальной поддержки ветеранов в Челябинской области"
#
#
# Статья 1. Лица, на которых распространяется действие настоящего Закона
#
# 1. Действие настоящего Затона распространяется на граждан Российской Федерации, а также на постоянно п...
# --------------------------------------------------------------------------------
