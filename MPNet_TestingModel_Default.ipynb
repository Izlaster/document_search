# %%
import os
import faiss
import shutil
import numpy as np
from sentence_transformers import SentenceTransformer

# %% [markdown]
# ## Указать все пути
# MODEL_NAME - путь к предобученной модели (уже указан)
# TEXT_FILES_DIR - путь к директории с текстами
# FAISS_INDEX_PATH - путь для сохранения/загрузки FAISS-индекса
# FILENAMES_PATH - путь для сохранения/загрузки списка имен файлов
# VECTORS_PATH - путь к папке с векторами

# %%
MODEL_NAME = "sentence-transformers/paraphrase-multilingual-mpnet-base-v2"
TEXT_FILES_DIR = "garant"
FAISS_INDEX_PATH = "results_MPNet_Default/text_index.faiss"
FILENAMES_PATH = "results_MPNet_Default/filenames.npy"
VECTORS_PATH = "results_MPNet_Default/vectors"

# %%
model = SentenceTransformer(MODEL_NAME)
index = faiss.read_index(FAISS_INDEX_PATH)
filenames = np.load(FILENAMES_PATH, allow_pickle=True)

# %% [markdown]
# ## Функция разбиения длинных текстов на чанки

# %%
def split_text_by_length(text, max_length=1000):
    words = text.split()
    chunks = []
    current_chunk = ""
    for word in words:
        if len(current_chunk) + len(word) + 1 <= max_length:
            current_chunk = current_chunk + " " + word if current_chunk else word
        else:
            chunks.append(current_chunk)
            current_chunk = word
    if current_chunk:
        chunks.append(current_chunk)
    return chunks

# %% [markdown]
# ## Функция для вычисления эмбеддинга с учётом разбиения длинного текста

# %%
def get_document_embedding(text, model, chunk_size=1000):
    if len(text) <= chunk_size:
        return model.encode(text)
    else:
        chunks = split_text_by_length(text, max_length=chunk_size)
        chunk_embeddings = model.encode(chunks, convert_to_numpy=True)
        return np.mean(chunk_embeddings, axis=0)

# %% [markdown]
# ## Функция поиска похожих текстов

# %%
def find_similar_texts_from_file(file_path, top_k=5):
    os.makedirs(VECTORS_PATH, exist_ok=True)
    
    with open(file_path, "r", encoding="utf-8") as f:
        query_text = f.read().strip()
    
    query_embedding = model.encode([query_text], convert_to_numpy=True)
    query_embedding = query_embedding / np.linalg.norm(query_embedding, axis=1, keepdims=True)
    
    base_filename = os.path.splitext(os.path.basename(file_path))[0]  # Убираем расширение
    vector_file_path = os.path.join(VECTORS_PATH, base_filename + ".txt")
    np.savetxt(vector_file_path, query_embedding, delimiter=",", fmt="%.6f")
    
    distances, indices = index.search(query_embedding.astype('float32'), top_k)
    
    print("Наиболее похожие тексты:")
    for i, idx in enumerate(indices[0]):
        text_filename = filenames[idx]
        similarity = max(0, (1 - distances[0][i] / 2)) * 100
        
        found_file_path = os.path.join(TEXT_FILES_DIR, text_filename)
        base_text_filename = os.path.splitext(text_filename)[0]  # Убираем расширение
        vector_output_path = os.path.join(VECTORS_PATH, base_text_filename + ".txt")
        
        if os.path.exists(found_file_path):
            with open(found_file_path, "r", encoding="utf-8") as f:
                full_text = f.read()
            
            text_embedding = model.encode([full_text], convert_to_numpy=True)
            text_embedding = text_embedding / np.linalg.norm(text_embedding, axis=1, keepdims=True)
            np.savetxt(vector_output_path, text_embedding, delimiter=",", fmt="%.6f")
            
            print(f"{i+1}. {text_filename} (схожесть: {similarity:.2f}%)")
            print(full_text[:300] + "...")
        else:
            print(f"{i+1}. {text_filename} [Файл не найден]")
        
        print("-" * 80)

# %% [markdown]
# ## Очистка

# %%
def clear_vectors_path():
    if not os.path.exists(VECTORS_PATH):
        print(f"Путь {VECTORS_PATH} не существует.")
        return

    for entry in os.listdir(VECTORS_PATH):
        entry_path = os.path.join(VECTORS_PATH, entry)
        try:
            if os.path.isfile(entry_path) or os.path.islink(entry_path):
                os.remove(entry_path)
            elif os.path.isdir(entry_path):
                shutil.rmtree(entry_path)
        except Exception as e:
            print(f"Не удалось удалить {entry_path}: {e}")
            
clear_vectors_path()

# %% [markdown]
# ## Тестирование
# file_path - путь к текстовому файлу, который будет поступать на вход

# %%
file_path = "garant.txt"

# %%
find_similar_texts_from_file(file_path, top_k=20)
# Out:
# Наиболее похожие тексты:
# 1. garant_1261.txt (схожесть: 100.00%)
# ﻿
# Постановление Мэра г. Хабаровска
# от 11 ноября 2004 г. N 1650
# "О проведении Международного дня инвалидов в городе Хабаровске в 2004 году"
#
# В связи с проведением 3 декабря 2004 года Международного дня инвалидов и в целях привлечения внимания широких слоев общественности города, предприятий, учрежден...
# --------------------------------------------------------------------------------
# 2. garant_1425.txt (схожесть: 82.48%)
# ﻿
# Постановление Главы города Челябинска
# от 8 июня 2004 г. N 991-п
# "Об утверждении "Программы мероприятий, обеспечивающих доступ инвалидов и
# маломобильных групп населения в существующие здания общественного
# назначения"
#
# В целях реализации постановления Главы города от 18.02.2003г. N 240-п "О бесп...
# --------------------------------------------------------------------------------
# 3. garant_1851.txt (схожесть: 80.84%)
# ﻿
# Решение Казанского Совета народных депутатов
# от 1 октября 2004 г. N 22-20
# "О мерах по поддержке общероссийских
# общественных организаций инвалидов"
#
# Рассмотрев обращение Татарской республиканской организации Всероссийского общества инвалидов - Общество инвалидов Республики Татарстан, принимая во вн...
# --------------------------------------------------------------------------------
# 4. garant_0055.txt (схожесть: 80.29%)
# ﻿
# Постановление Губернатора Ярославской области
# от 21 декабря 2004 г. N 859
# "О квотировании рабочих мест для трудоустройства инвалидов"
#
# В соответствии с Федеральным законом от 24.11.95 N 181-ФЗ "О социальной защите инвалидов в Российской Федерации" и в целях установления гарантии трудовой занятости...
# --------------------------------------------------------------------------------
# 5. garant_1338.txt (схожесть: 78.95%)
# ﻿
# Постановление Губернатора Ярославской области
# от 30 ноября 2004 г. N 800
# "О дополнительных мерах социальной поддержки участников и
# инвалидов Великой Отечественной войны в 2005 году"
#
# Ярославской области
# от 16 декабря 2004 г. N 3111
# "О мерах социальной поддержки отдельных категорий граждан"
#
# В целях сдерживания роста тарифов на проезд в муниципальном городском общественном транспорте для работающего населения, для сохранения ...
# --------------------------------------------------------------------------------
# 14. garant_0291.txt (схожесть: 67.25%)
# ﻿Зарегистрировано в Минюсте РФ 22 декабря 2004 г.
# Регистрационный N 6226
#
#       Приказ Министерства здравоохранения и социального развития РФ
#                        от 29 ноября 2004 г. N 287
#   "Об утверждении формы индивидуальной программы реабилитации инвалида,
#    выдаваемой федеральными учреждени...
# --------------------------------------------------------------------------------
# 15. garant_1007.txt (схожесть: 67.07%)
# ﻿
# Постановление Администрации Новгородской области
# от 29 декабря 2004 г. N 301
# "О Порядке обеспечения социальных работников, занятых в государственном
# секторе социального обслуживания населения, специальной одеждой, обувью и
# инвентарем или выплаты денежной компенсации на их приобретение"
#
# Во испо...
# --------------------------------------------------------------------------------
# 16. garant_0160.txt (схожесть: 66.81%)
# ﻿Распоряжение Правительства Москвы от 3 ноября 2004 г. № 2202-РП
# «О  компенсации  расходов на обязательное страхование  гражданской ответственности инвалидам-владельцам транспортных средств»
#
#      В соответствии  с  Федеральным законом от 25 апреля 2002 года N 40-ФЗ "Об обязательном  страховании  гр...
# --------------------------------------------------------------------------------
# 17. garant_1220.txt (схожесть: 66.42%)
# ﻿
# Закон Иркутской области от 7 октября 2004 г. N 50-ОЗ
# "О социальной поддержке отдельных групп населения в оказании
# медико-социальной помощи в Иркутской области"
#
# Принят Постановлением Законодательного собрания Иркутской области от 22 сентября 2004 г. N 40/12а-ЗС
#
#               населения            ...
# --------------------------------------------------------------------------------
# 18. garant_1281.txt (схожесть: 66.26%)
# ﻿
# Закон Челябинской области
# от 30 ноября 2004 г. N 321-ЗО
# "О наделении органов местного самоуправления государственными
# полномочиями в сфере социального обслуживания населения"
#
#
# Статья 1. Наделить государственными полномочиями по социальному обслуживанию граждан пожилого возраста и инвалидов, г...
# --------------------------------------------------------------------------------
# 19. garant_1121.txt (схожесть: 64.95%)
# ﻿
# Постановление Главы администрации Полесского района Калининградской
# области от 22 сентября 2004 г. N 795
# "Об органе опеки и попечительства над совершеннолетними гражданами"
#
# В целях совершенствования деятельности по защите законных прав и интересов недееспособных или не полностью дееспособных граж...
# --------------------------------------------------------------------------------
# 20. garant_1118.txt (схожесть: 64.64%)
# ﻿
# Постановление Псковской городской Думы
# от 29 декабря 2004 г. N 349
# "О социальной поддержке пенсионеров, не обладающих правом на региональные
# и федеральные льготы по проезду в городском пассажирском транспорте"
#
# Принято на 32-й сессии Псковской городской Думы 3-го созыва
#
# С целью реализации муницип...
# --------------------------------------------------------------------------------
