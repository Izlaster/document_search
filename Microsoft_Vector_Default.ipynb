# %%
import os
import faiss
import numpy as np
from tqdm import tqdm
from sentence_transformers import SentenceTransformer

# %% [markdown]
# ## Этап 1. Загрузка текстов из файлов

# %%
TEXT_FILES_DIR = "garant"

# %%
def load_texts_from_folder(folder_path):
    texts = []
    filenames = []
    for file in tqdm(sorted(os.listdir(folder_path)), desc="Загрузка текстов"):
        if file.endswith(".txt"):
            file_path = os.path.join(folder_path, file)
            with open(file_path, "r", encoding="utf-8") as f:
                text = f.read().strip()
                texts.append(text)
                filenames.append(file)
    return texts, filenames

# %%
texts, filenames = load_texts_from_folder(TEXT_FILES_DIR)
# Out:
# Загрузка текстов: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████| 1628/1628 [00:02<00:00, 634.12it/s]

# %% [markdown]
# ## Этап 2. Создание эмбеддингов

# %%
MODEL_NAME = "intfloat/multilingual-e5-large"
model = SentenceTransformer(MODEL_NAME)

# %%
text_embeddings = model.encode(texts, batch_size=16, convert_to_numpy=True, show_progress_bar=True)
print(f"\nРазмерность эмбеддингов: {text_embeddings.shape}")
# Out:
# Batches:   0%|          | 0/102 [00:00<?, ?it/s]
# Размерность эмбеддингов: (1628, 1024)

# %% [markdown]
# ## Этап 3: Создание FAISS-индекса

# %% [markdown]
# FAISS используется для быстрого поиска среди эмбеддингов

# %%
norms = np.linalg.norm(text_embeddings, axis=1, keepdims=True)
text_embeddings_normalized = text_embeddings / norms
dimension = text_embeddings.shape[1]

# %% [markdown]
# Создаём FAISS-индекс

# %%
index = faiss.IndexFlatL2(dimension)
index.add(text_embeddings_normalized.astype('float32'))

# %% [markdown]
# Сохраняем индекс для последующего использования

# %%
faiss.write_index(index, "results_Microsoft_Default/text_index.faiss")
np.save("results_Microsoft_Default/filenames.npy", np.array(filenames))  # сохраняем список имён файлов

# %% [markdown]
# ## Этап 4: Функция поиска похожих текстов

# %%
def find_similar_texts(query, top_k=5):
    query_embedding = model.encode([query], convert_to_numpy=True) # преобразуем запрос в эмбеддинг
    distances, indices = index.search(query_embedding, top_k) # выполняем поиск в FAISS

    print("Наиболее похожие тексты:")
    for i, idx in enumerate(indices[0]):
        print(f"{i+1}. {filenames[idx]} (дистанция: {distances[0][i]:.4f})")
        print(texts[idx][:300] + "...")  # выводим первые 300 символов текста
        print("-" * 80)

# %%
query_text = "Международный день инвалидов в Хабаровске"
find_similar_texts(query_text, top_k=20)
# Out:
# Наиболее похожие тексты:
# 1. garant_1261.txt (дистанция: 0.2817)
# ﻿
# Постановление Мэра г. Хабаровска
# от 11 ноября 2004 г. N 1650
# "О проведении Международного дня инвалидов в городе Хабаровске в 2004 году"
#
# В связи с проведением 3 декабря 2004 года Международного дня инвалидов и в целях привлечения внимания широких слоев общественности города, предприятий, учрежден...
# --------------------------------------------------------------------------------
# 2. garant_0291.txt (дистанция: 0.4202)
# ﻿Зарегистрировано в Минюсте РФ 22 декабря 2004 г.
# Регистрационный N 6226
#
#       Приказ Министерства здравоохранения и социального развития РФ
#                        от 29 ноября 2004 г. N 287
#   "Об утверждении формы индивидуальной программы реабилитации инвалида,
#    выдаваемой федеральными учреждени...
# --------------------------------------------------------------------------------
# 3. garant_0522.txt (дистанция: 0.4229)
# ﻿
# Постановление Мэра г. Хабаровска
# от 1 декабря 2004 г. N 1762
# "О проведении в 2005 году творческого конкурса средств массовой
# информации г. Хабаровска, посвященного 60-летию Победы в Великой
# Отечественной войне"
#
# В ознаменование предстоящего 9 мая 2005 года 60-летия Победы советского народа в Велик...
# --------------------------------------------------------------------------------
# 4. garant_1851.txt (дистанция: 0.4243)
# ﻿
# Решение Казанского Совета народных депутатов
# от 1 октября 2004 г. N 22-20
# "О мерах по поддержке общероссийских
# общественных организаций инвалидов"
#
# Рассмотрев обращение Татарской республиканской организации Всероссийского общества инвалидов - Общество инвалидов Республики Татарстан, принимая во вн...
# --------------------------------------------------------------------------------
# 5. garant_0078.txt (дистанция: 0.4294)
# ﻿
# Постановление Мэра г. Хабаровска
# от 12 ноября 2004 г. N 1662
# "О городском смотре-конкурсе на лучшую организацию органами студенческого
# (ученического) самоуправления социально-значимого досуга в общежитиях
# учебных заведений города"
#
# В соответствии с основными направлениями реализации Городской ко...
# --------------------------------------------------------------------------------
# 6. garant_1425.txt (дистанция: 0.4317)
# ﻿
# Постановление Главы города Челябинска
# от 8 июня 2004 г. N 991-п
# "Об утверждении "Программы мероприятий, обеспечивающих доступ инвалидов и
# маломобильных групп населения в существующие здания общественного
# назначения"
#
# В целях реализации постановления Главы города от 18.02.2003г. N 240-п "О бесп...
# --------------------------------------------------------------------------------
# 7. garant_0468.txt (дистанция: 0.4370)
# ﻿
# Постановление Главы города Лермонтова
# от 26 ноября 2004 г. N 451
# "О квотировании рабочих мест для инвалидов на предприятиях,
# организациях и учреждениях города Лермонтова"
#
# В соответствии с Федеральным законом "О социальной защите инвалидов в Российской Федерации, законом Российской Федерации "О за...
# --------------------------------------------------------------------------------
# 8. garant_0593.txt (дистанция: 0.4397)
# ﻿
# Постановление Губернатора Хабаровского края
# от 6 сентября 2004 г. N 231
# "О дополнительных мерах по предупреждению проявлений террористической
# направленности и повышению бдительности на территории Хабаровского края"
#
# В связи с совершением ряда террористических актов в городах Российской Федерации, ...
# --------------------------------------------------------------------------------
# 9. garant_0976.txt (дистанция: 0.4397)
# ﻿
# Постановление Городской Думы города Нижнего Новгорода
# от 29 сентября 2004 г. N 67
# "О предоставлении льготы по земельному налогу"
#
# В соответствии со ст.14 Закона Российской Федерации "О плате за землю", ст.22 Устава города Нижнего Новгорода и в целях оказания поддержки в решении социальных проблем ...
# --------------------------------------------------------------------------------
# 10. garant_0061.txt (дистанция: 0.4419)
# ﻿
# Постановление Администрации Ярославской области
# от 22 декабря 2004 г. N 192-а
# "Об утверждении Порядка воспитания и обучения детей-инвалидов
# на дому"
#
# В соответствии с федеральными законами от 24.11.95 N 181-ФЗ "О социальной защите инвалидов в Российской Федерации", от 22.08.2004 N 122-ФЗ "О внесен...
# --------------------------------------------------------------------------------
# 11. garant_1338.txt (дистанция: 0.4476)
# ﻿
# Постановление Губернатора Ярославской области
# от 30 ноября 2004 г. N 800
# "О дополнительных мерах социальной поддержки участников и
# инвалидов Великой Отечественной войны в 2005 году"
#
# В целях социальной поддержки участников и инвалидов Великой Отечественной войны в год 60-летия Победы постановляю:
# ...
# --------------------------------------------------------------------------------
# 12. garant_1356.txt (дистанция: 0.4479)
# ﻿
# Распоряжение Мэра г. Хабаровска
# от 21 мая 2004 г. N 1110-р
# "О мерах по укреплению пожарной безопасности на весенне-летний период
# 2004 года"
#
# За три месяца 2004 года в г. Хабаровске произошло 406 пожаров, материальный ущерб от которых составил 2079,9 тысячи рублей. Погибли в пожарах 27 человек.
# За ...
# --------------------------------------------------------------------------------
# 13. garant_1337.txt (дистанция: 0.4480)
# ﻿
# Постановление Правительства УР от 17 мая 2004 г. N 64
# "О ежегодных денежных компенсациях расходов, связанных с эксплуатацией
# транспортных средств, и транспортных расходов инвалидам"
#
# В соответствии с Федеральными законами "О социальной защите инвалидов в Российской Федерации" и "О ветеранах" Прави...
# --------------------------------------------------------------------------------
# 14. garant_0953.txt (дистанция: 0.4510)
# ﻿
# Закон Республики Хакасия
# от 11 ноября 2004 г. N 85
# "О мерах социальной поддержки реабилитированных лиц
# и лиц, признанных пострадавшими от политических репрессий"
# (Принят Верховным Советом Республики Хакасия 27 октября 2004 г.)
#
# Настоящий Закон в соответствии с Законом Российской Федерации от 18 ...
# --------------------------------------------------------------------------------
# 15. garant_0714.txt (дистанция: 0.4525)
# ﻿
# Распоряжение Мэра г.Сургута от 30 ноября 2004 г. N 4478
# "О компенсационных выплатах на питание обучающихся в общеобразовательных учреждениях"
#
# В соответствии с Федеральным законом от 01.08.1996 N 107-ФЗ "О компенсационных выплатах на питание обучающихся в государственных, муниципальных общеобразов...
# --------------------------------------------------------------------------------
# 16. garant_2063.txt (дистанция: 0.4563)
# ﻿
# Постановление Мэра г. Хабаровска
# от 13 сентября 2004 г. N 1370/1
# "О проведении мероприятий по призыву граждан призывных возрастов на
# военную службу осенью 2004 года и обеспечении этих мероприятий"
#
# В соответствии с Законом Российской Федерации от 28.03.98 N 53-ФЗ "О воинской обязанности и военной ...
# --------------------------------------------------------------------------------
# 17. garant_1291.txt (дистанция: 0.4568)
# ﻿
# Информация отделения Пенсионного фонда Российской Федерации
# по Республике Башкортостан
# от 21 октября 2004 г.
# "Все о ежемесячной денежной выплате"
#
# Федеральным законом от 22.08.2004 N 122-ФЗ внесены изменения в Федеральные законы "О ветеранах", "О социальной защите инвалидов в Российской Федерации"...
# --------------------------------------------------------------------------------
# 18. garant_0721.txt (дистанция: 0.4578)
# ﻿
# Закон Тамбовской области от 30 ноября 2004 г. N 256-З
# "О мерах социальной поддержки тружеников тыла, ветеранов
# труда и лиц, к ним приравненных"
# (принят Тамбовской областной Думой 30 ноября 2004 г.)
#
# Настоящий Закон устанавливает на территории Тамбовской области правовые гарантии социальной поддерж...
# --------------------------------------------------------------------------------
# 19. garant_0111.txt (дистанция: 0.4578)
# ﻿
# Постановление Правительства Ханты-Мансийского АО - Югры от 25 ноября 2004 г. N 454-п
# "О выплате единовременной материальной помощи неработающим пенсионерам,
# проживающим на территории автономного округа"
#
# В целях реализации постановления Губернатора автономного округа от 18 июня 2002 года N 101 "О ...
# --------------------------------------------------------------------------------
# 20. garant_1231.txt (дистанция: 0.4579)
# ﻿
# Постановление Правительства Ленинградской области
# от 23 декабря 2004 г. N 312
# "Об утверждении Положения о порядке обеспечения
# протезно-ортопедической помощью лиц, проработавших в тылу
# в период с 22 июня 1941 года по 9 мая 1945 года не менее шести
# месяцев, исключая период работы на временно оккупир...
# --------------------------------------------------------------------------------
